# %%
# VGG16 Transfer Learning - Fixed Version for High Accuracy

# =========================
# 1. Import Libraries
# =========================
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

# =========================
# 2. Load Dataset
# =========================
data_dir = r"D:\SmartVision\DataSets\smartvision_dataset\classification"







img_size = (224, 224)
batch_size = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir + "/train",
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir + "/val",
    image_size=img_size,
    batch_size=batch_size
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir + "/test",
    image_size=img_size,
    batch_size=batch_size
)

# Save class names
class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

# =========================
# 3. Data Augmentation
# =========================
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# =========================
# 4. Preprocessing (VGG16)
# =========================
train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y))

# =========================
# 5. Performance Optimization
# =========================
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# =========================
# 6. Load VGG16 Base Model
# =========================
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

# Freeze layers
for layer in base_model.layers:
    layer.trainable = False

# =========================
# 7. Custom Classifier
# =========================
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(512, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)

output = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=output)

# =========================
# 8. Compile Model
# =========================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# =========================
# 9. Callbacks
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("vgg16_best_model.h5", save_best_only=True, monitor='val_accuracy'),
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.3, patience=3)
]

# =========================
# 10. Train Model
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=25,
    callbacks=callbacks
)

# =========================
# 11. Fine-Tuning
# =========================
for layer in base_model.layers[-8:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_finetune = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

# =========================
# 12. Evaluate Model
# =========================
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)

# =========================
# 13. Plot Results
# =========================
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss")
plt.show()
# Out:
# Found 1820 files belonging to 26 classes.
# Found 390 files belonging to 26 classes.
# Found 390 files belonging to 26 classes.
# Classes: ['airplane', 'bed', 'bench', 'bicycle', 'bird', 'bottle', 'bowl', 'bus', 'cake', 'car', 'cat', 'chair', 'couch', 'cow', 'cup', 'dog', 'elephant', 'horse', 'motorcycle', 'person', 'pizza', 'potted plant', 'stop sign', 'traffic light', 'train', 'truck']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 26)             │         6,682 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,117,402 (57.67 MB)
#  Trainable params: 401,690 (1.53 MB)
#  Non-trainable params: 14,715,712 (56.14 MB)
# Epoch 1/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.0584 - loss: 4.5108
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 858s 13s/step - accuracy: 0.0654 - loss: 4.3556 - val_accuracy: 0.1026 - val_loss: 3.6901 - learning_rate: 1.0000e-04
# Epoch 2/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.1146 - loss: 3.6202
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 751s 13s/step - accuracy: 0.1291 - loss: 3.5000 - val_accuracy: 0.1923 - val_loss: 2.9644 - learning_rate: 1.0000e-04
# Epoch 3/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.1882 - loss: 3.1182
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 755s 13s/step - accuracy: 0.2077 - loss: 2.9950 - val_accuracy: 0.3000 - val_loss: 2.6429 - learning_rate: 1.0000e-04
# Epoch 4/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.2714 - loss: 2.6742
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 758s 13s/step - accuracy: 0.2753 - loss: 2.6370 - val_accuracy: 0.3462 - val_loss: 2.4541 - learning_rate: 1.0000e-04
# Epoch 5/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.3273 - loss: 2.4289
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 752s 13s/step - accuracy: 0.3505 - loss: 2.3188 - val_accuracy: 0.3564 - val_loss: 2.3252 - learning_rate: 1.0000e-04
# Epoch 6/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.4040 - loss: 2.1271
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 738s 13s/step - accuracy: 0.3978 - loss: 2.1366 - val_accuracy: 0.3615 - val_loss: 2.2512 - learning_rate: 1.0000e-04
# Epoch 7/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.4606 - loss: 1.9535
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 733s 13s/step - accuracy: 0.4604 - loss: 1.9283 - val_accuracy: 0.3744 - val_loss: 2.2055 - learning_rate: 1.0000e-04
# Epoch 8/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.4810 - loss: 1.8661
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 736s 13s/step - accuracy: 0.4973 - loss: 1.8017 - val_accuracy: 0.3923 - val_loss: 2.1649 - learning_rate: 1.0000e-04
# Epoch 9/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.4943 - loss: 1.7936
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 735s 13s/step - accuracy: 0.5159 - loss: 1.7218 - val_accuracy: 0.3949 - val_loss: 2.1312 - learning_rate: 1.0000e-04
# Epoch 10/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 733s 13s/step - accuracy: 0.5604 - loss: 1.5799 - val_accuracy: 0.3949 - val_loss: 2.1074 - learning_rate: 1.0000e-04
# Epoch 11/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 732s 13s/step - accuracy: 0.5747 - loss: 1.5004 - val_accuracy: 0.3923 - val_loss: 2.0951 - learning_rate: 1.0000e-04
# Epoch 12/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 733s 13s/step - accuracy: 0.5896 - loss: 1.3923 - val_accuracy: 0.3949 - val_loss: 2.0845 - learning_rate: 1.0000e-04
# Epoch 13/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.6168 - loss: 1.3711
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 732s 13s/step - accuracy: 0.6269 - loss: 1.3213 - val_accuracy: 0.4026 - val_loss: 2.0699 - learning_rate: 1.0000e-04
# Epoch 14/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 726s 13s/step - accuracy: 0.6462 - loss: 1.2615 - val_accuracy: 0.3949 - val_loss: 2.0579 - learning_rate: 1.0000e-04
# Epoch 15/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 724s 13s/step - accuracy: 0.6511 - loss: 1.2407 - val_accuracy: 0.3949 - val_loss: 2.0609 - learning_rate: 1.0000e-04
# Epoch 16/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.6428 - loss: 1.1703
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 747s 13s/step - accuracy: 0.6577 - loss: 1.1394 - val_accuracy: 0.4077 - val_loss: 2.0538 - learning_rate: 1.0000e-04
# Epoch 17/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 734s 13s/step - accuracy: 0.6978 - loss: 1.0720 - val_accuracy: 0.4077 - val_loss: 2.0571 - learning_rate: 1.0000e-04
# Epoch 18/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.6910 - loss: 1.0626
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 732s 13s/step - accuracy: 0.7022 - loss: 1.0373 - val_accuracy: 0.4179 - val_loss: 2.0302 - learning_rate: 1.0000e-04
# Epoch 19/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7388 - loss: 0.9523
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 734s 13s/step - accuracy: 0.7357 - loss: 0.9446 - val_accuracy: 0.4231 - val_loss: 2.0302 - learning_rate: 1.0000e-04
# Epoch 20/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7381 - loss: 0.9579
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 731s 13s/step - accuracy: 0.7357 - loss: 0.9535 - val_accuracy: 0.4308 - val_loss: 2.0328 - learning_rate: 1.0000e-04
# Epoch 21/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7610 - loss: 0.8887
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 732s 13s/step - accuracy: 0.7577 - loss: 0.8921 - val_accuracy: 0.4359 - val_loss: 2.0301 - learning_rate: 1.0000e-04
# Epoch 22/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 724s 13s/step - accuracy: 0.7544 - loss: 0.8487 - val_accuracy: 0.4308 - val_loss: 2.0227 - learning_rate: 1.0000e-04
# Epoch 23/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 724s 13s/step - accuracy: 0.7698 - loss: 0.8102 - val_accuracy: 0.4179 - val_loss: 2.0177 - learning_rate: 1.0000e-04
# Epoch 24/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 716s 13s/step - accuracy: 0.7764 - loss: 0.7789 - val_accuracy: 0.4333 - val_loss: 2.0371 - learning_rate: 1.0000e-04
# Epoch 25/25
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 659s 12s/step - accuracy: 0.7791 - loss: 0.7605 - val_accuracy: 0.4359 - val_loss: 2.0378 - learning_rate: 1.0000e-04
# Epoch 1/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1347s 24s/step - accuracy: 0.7676 - loss: 0.8209 - val_accuracy: 0.4308 - val_loss: 2.0462
# Epoch 2/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1343s 24s/step - accuracy: 0.7918 - loss: 0.7636 - val_accuracy: 0.4308 - val_loss: 1.9946
# Epoch 3/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1342s 24s/step - accuracy: 0.8225 - loss: 0.6574 - val_accuracy: 0.4410 - val_loss: 2.0010
# Epoch 4/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1342s 24s/step - accuracy: 0.8247 - loss: 0.6322 - val_accuracy: 0.4462 - val_loss: 1.9579
# Epoch 5/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1337s 23s/step - accuracy: 0.8467 - loss: 0.5753 - val_accuracy: 0.4333 - val_loss: 1.9912
# Epoch 6/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1340s 24s/step - accuracy: 0.8511 - loss: 0.5470 - val_accuracy: 0.4410 - val_loss: 1.9552
# Epoch 7/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1333s 23s/step - accuracy: 0.8879 - loss: 0.4846 - val_accuracy: 0.4385 - val_loss: 1.9571
# Epoch 8/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 18453s 329s/step - accuracy: 0.8830 - loss: 0.4705 - val_accuracy: 0.4410 - val_loss: 1.9821
# Epoch 9/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1542s 27s/step - accuracy: 0.9049 - loss: 0.4259 - val_accuracy: 0.4487 - val_loss: 1.9755
# Epoch 10/10
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1442s 25s/step - accuracy: 0.9088 - loss: 0.4026 - val_accuracy: 0.4308 - val_loss: 1.9648
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 129s 9s/step - accuracy: 0.4000 - loss: 2.1242
# Test Accuracy: 0.4000000059604645
