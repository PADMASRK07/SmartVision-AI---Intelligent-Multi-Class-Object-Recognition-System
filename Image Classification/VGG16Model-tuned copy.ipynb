# %%
# VGG16 Transfer Learning - Fixed Version for High Accuracy

# =========================
# 1. Import Libraries
# =========================
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import layers, models
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input

# =========================
# 2. Load Dataset
# =========================
data_dir = r"D:\SmartVision\DataSets\smartvision_dataset\classification"
img_size = (224, 224)
batch_size = 32

train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir + "/train",
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir + "/val",
    image_size=img_size,
    batch_size=batch_size
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir + "/test",
    image_size=img_size,
    batch_size=batch_size
)

# Save class names
class_names = train_ds.class_names
NUM_CLASSES = len(class_names)
print("Classes:", class_names)

# =========================
# 3. Data Augmentation
# =========================
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

train_ds = train_ds.map(lambda x, y: (data_augmentation(x, training=True), y))

# =========================
# 4. Preprocessing (VGG16)
# =========================
train_ds = train_ds.map(lambda x, y: (preprocess_input(x), y))
val_ds = val_ds.map(lambda x, y: (preprocess_input(x), y))
test_ds = test_ds.map(lambda x, y: (preprocess_input(x), y))

# =========================
# 5. Performance Optimization
# =========================
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.cache().prefetch(buffer_size=AUTOTUNE)

# =========================
# 6. Load VGG16 Base Model
# =========================
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224,224,3))

# Freeze layers
for layer in base_model.layers:
    layer.trainable = False

# =========================
# 7. Custom Classifier
# =========================
x = base_model.output
x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(512, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dropout(0.5)(x)

x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)

output = layers.Dense(NUM_CLASSES, activation='softmax')(x)

model = models.Model(inputs=base_model.input, outputs=output)

# =========================
# 8. Compile Model
# =========================
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()

# =========================
# 9. Callbacks
# =========================
callbacks = [
    tf.keras.callbacks.ModelCheckpoint("vgg16_best_model.h5", save_best_only=True, monitor='val_accuracy'),
    tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(factor=0.3, patience=3)
]

# =========================
# 10. Train Model
# =========================
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=40,
    callbacks=callbacks
)

# =========================
# 11. Fine-Tuning
# =========================
for layer in base_model.layers[-8:]:
    layer.trainable = True

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history_finetune = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20
)

# =========================
# 12. Evaluate Model
# =========================
test_loss, test_acc = model.evaluate(test_ds)
print("Test Accuracy:", test_acc)

# =========================
# 13. Plot Results
# =========================
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title("Loss")
plt.show()
# Out:
# Found 1820 files belonging to 26 classes.
# Found 390 files belonging to 26 classes.
# Found 390 files belonging to 26 classes.
# Classes: ['airplane', 'bed', 'bench', 'bicycle', 'bird', 'bottle', 'bowl', 'bus', 'cake', 'car', 'cat', 'chair', 'couch', 'cow', 'cup', 'dog', 'elephant', 'horse', 'motorcycle', 'person', 'pizza', 'potted plant', 'stop sign', 'traffic light', 'train', 'truck']
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 224, 224, 64)   │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 224, 224, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 56, 56, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 56, 56, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 28, 28, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 28, 28, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 14, 14, 512)    │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 26)             │         6,682 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 15,117,402 (57.67 MB)
#  Trainable params: 401,690 (1.53 MB)
#  Non-trainable params: 14,715,712 (56.14 MB)
# Epoch 1/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.0559 - loss: 4.4588
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 829s 13s/step - accuracy: 0.0582 - loss: 4.2241 - val_accuracy: 0.1077 - val_loss: 3.4931 - learning_rate: 1.0000e-04
# Epoch 2/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.1296 - loss: 3.4988
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 725s 13s/step - accuracy: 0.1484 - loss: 3.3723 - val_accuracy: 0.2231 - val_loss: 2.9700 - learning_rate: 1.0000e-04
# Epoch 3/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 10s/step - accuracy: 0.1975 - loss: 3.0625
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 725s 13s/step - accuracy: 0.2297 - loss: 2.9161 - val_accuracy: 0.2513 - val_loss: 2.7355 - learning_rate: 1.0000e-04
# Epoch 4/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.3154 - loss: 2.5082
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 729s 13s/step - accuracy: 0.3011 - loss: 2.5341 - val_accuracy: 0.2897 - val_loss: 2.5757 - learning_rate: 1.0000e-04
# Epoch 5/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.3175 - loss: 2.4096
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 731s 13s/step - accuracy: 0.3341 - loss: 2.3733 - val_accuracy: 0.3077 - val_loss: 2.4591 - learning_rate: 1.0000e-04
# Epoch 6/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.3901 - loss: 2.1207
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 730s 13s/step - accuracy: 0.3995 - loss: 2.1223 - val_accuracy: 0.3231 - val_loss: 2.3732 - learning_rate: 1.0000e-04
# Epoch 7/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.4265 - loss: 2.0231
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 730s 13s/step - accuracy: 0.4308 - loss: 1.9860 - val_accuracy: 0.3462 - val_loss: 2.3338 - learning_rate: 1.0000e-04
# Epoch 8/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 726s 13s/step - accuracy: 0.4879 - loss: 1.8301 - val_accuracy: 0.3462 - val_loss: 2.2976 - learning_rate: 1.0000e-04
# Epoch 9/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.5048 - loss: 1.7546
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 730s 13s/step - accuracy: 0.5088 - loss: 1.7197 - val_accuracy: 0.3769 - val_loss: 2.2519 - learning_rate: 1.0000e-04
# Epoch 10/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 726s 13s/step - accuracy: 0.5511 - loss: 1.6050 - val_accuracy: 0.3769 - val_loss: 2.2301 - learning_rate: 1.0000e-04
# Epoch 11/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.5804 - loss: 1.5033
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 727s 13s/step - accuracy: 0.5736 - loss: 1.5237 - val_accuracy: 0.3821 - val_loss: 2.2054 - learning_rate: 1.0000e-04
# Epoch 12/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.5822 - loss: 1.4116
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 740s 13s/step - accuracy: 0.5896 - loss: 1.4098 - val_accuracy: 0.4154 - val_loss: 2.1903 - learning_rate: 1.0000e-04
# Epoch 13/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 731s 13s/step - accuracy: 0.6093 - loss: 1.3708 - val_accuracy: 0.4077 - val_loss: 2.1896 - learning_rate: 1.0000e-04
# Epoch 14/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 735s 13s/step - accuracy: 0.6264 - loss: 1.3078 - val_accuracy: 0.4026 - val_loss: 2.1946 - learning_rate: 1.0000e-04
# Epoch 15/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.6564 - loss: 1.2221
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 735s 13s/step - accuracy: 0.6610 - loss: 1.1965 - val_accuracy: 0.4231 - val_loss: 2.1794 - learning_rate: 1.0000e-04
# Epoch 16/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 727s 13s/step - accuracy: 0.6670 - loss: 1.1788 - val_accuracy: 0.4231 - val_loss: 2.1711 - learning_rate: 1.0000e-04
# Epoch 17/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.6942 - loss: 1.0898
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 732s 13s/step - accuracy: 0.6956 - loss: 1.0975 - val_accuracy: 0.4385 - val_loss: 2.1658 - learning_rate: 1.0000e-04
# Epoch 18/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 728s 13s/step - accuracy: 0.6967 - loss: 1.0769 - val_accuracy: 0.4333 - val_loss: 2.1677 - learning_rate: 1.0000e-04
# Epoch 19/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 734s 13s/step - accuracy: 0.7110 - loss: 1.0313 - val_accuracy: 0.4282 - val_loss: 2.1714 - learning_rate: 1.0000e-04
# Epoch 20/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 729s 13s/step - accuracy: 0.7308 - loss: 0.9493 - val_accuracy: 0.4333 - val_loss: 2.1729 - learning_rate: 1.0000e-04
# Epoch 21/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7418 - loss: 0.9165
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 730s 13s/step - accuracy: 0.7308 - loss: 0.9596 - val_accuracy: 0.4487 - val_loss: 2.1695 - learning_rate: 3.0000e-05
# Epoch 22/40
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 11s/step - accuracy: 0.7521 - loss: 0.8930
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 732s 13s/step - accuracy: 0.7456 - loss: 0.9094 - val_accuracy: 0.4513 - val_loss: 2.1679 - learning_rate: 3.0000e-05
# Epoch 1/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1527s 27s/step - accuracy: 0.6709 - loss: 1.1296 - val_accuracy: 0.4256 - val_loss: 2.1471
# Epoch 2/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1502s 26s/step - accuracy: 0.7225 - loss: 0.9816 - val_accuracy: 0.4487 - val_loss: 2.1509
# Epoch 3/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1507s 26s/step - accuracy: 0.7418 - loss: 0.9384 - val_accuracy: 0.4590 - val_loss: 2.0850
# Epoch 4/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1504s 26s/step - accuracy: 0.7731 - loss: 0.8607 - val_accuracy: 0.4436 - val_loss: 2.0786
# Epoch 5/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1515s 27s/step - accuracy: 0.7841 - loss: 0.7738 - val_accuracy: 0.4641 - val_loss: 2.0680
# Epoch 6/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 9627s 171s/step - accuracy: 0.7984 - loss: 0.7512 - val_accuracy: 0.4538 - val_loss: 2.0538
# Epoch 7/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1514s 27s/step - accuracy: 0.8236 - loss: 0.6730 - val_accuracy: 0.4436 - val_loss: 2.0328
# Epoch 8/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1520s 27s/step - accuracy: 0.8308 - loss: 0.6602 - val_accuracy: 0.4385 - val_loss: 2.0182
# Epoch 9/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1505s 26s/step - accuracy: 0.8478 - loss: 0.6052 - val_accuracy: 0.4513 - val_loss: 2.0500
# Epoch 10/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1507s 26s/step - accuracy: 0.8544 - loss: 0.5635 - val_accuracy: 0.4590 - val_loss: 2.0066
# Epoch 11/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1499s 26s/step - accuracy: 0.8874 - loss: 0.4912 - val_accuracy: 0.4103 - val_loss: 2.0304
# Epoch 12/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1509s 27s/step - accuracy: 0.8901 - loss: 0.4715 - val_accuracy: 0.4487 - val_loss: 2.0183
# Epoch 13/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1511s 27s/step - accuracy: 0.9011 - loss: 0.4343 - val_accuracy: 0.4538 - val_loss: 2.0033
# Epoch 14/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1503s 26s/step - accuracy: 0.9027 - loss: 0.4214 - val_accuracy: 0.4769 - val_loss: 2.0563
# Epoch 15/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1500s 26s/step - accuracy: 0.9148 - loss: 0.4122 - val_accuracy: 0.4462 - val_loss: 2.0460
# Epoch 16/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1502s 26s/step - accuracy: 0.9176 - loss: 0.3764 - val_accuracy: 0.4615 - val_loss: 2.0311
# Epoch 17/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1506s 26s/step - accuracy: 0.9247 - loss: 0.3489 - val_accuracy: 0.4821 - val_loss: 2.0160
# Epoch 18/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1505s 26s/step - accuracy: 0.9275 - loss: 0.3459 - val_accuracy: 0.5051 - val_loss: 2.0153
# Epoch 19/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 1506s 26s/step - accuracy: 0.9253 - loss: 0.3321 - val_accuracy: 0.4744 - val_loss: 1.9871
# Epoch 20/20
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 21651s 386s/step - accuracy: 0.9396 - loss: 0.2955 - val_accuracy: 0.4718 - val_loss: 1.9880
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 161s 10s/step - accuracy: 0.3795 - loss: 2.3089
# Test Accuracy: 0.37948718667030334
